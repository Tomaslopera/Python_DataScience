# %% [markdown]
# # <center>Análisis Exploratorio de Peliculas<center>

# %%
import pandas as pd

# %%
df = pd.read_csv('../Python para Data Science/Datasets/Top-Películas.csv')

# %%
df.head()
# Out:
#   indice_global  indice_estricto                    título  \
# 0             0              0.0  The Shawshank Redemption
# 1             1              1.0             The Godfather
# 2             2              1.0             The Godfather
# 3             3              2.0           The Dark Knight
# 4             4              2.0           The Dark Knight
#
#                director     año  duración  género  rating  metascore  \
# 0        Frank Darabont  1994.0     142.0   Drama     9.3       82.0
# 1  Francis Ford Coppola  1972.0     175.0  Crimen     9.2      100.0
# 2  Francis Ford Coppola  1972.0     175.0   Drama     9.2      100.0
# 3     Christopher Nolan  2008.0     152.0  Acción     9.0       84.0
# 4     Christopher Nolan  2008.0     152.0  Crimen     9.0       84.0
#
#    recaudación(M)
# 0           28.34
# 1          134.97
# 2          134.97
# 3          534.86
# 4          534.86

# %%
df.describe()
# Out:
#        indice_estricto          año     duración       rating    metascore  \
# count      2489.000000  2489.000000  2489.000000  2489.000000  2489.000000
# mean        501.783849  1992.161511   124.421053     7.965689    66.522298
# std         290.438715    24.316534    28.977946     0.275025    30.447038
# min           0.000000  1920.000000    45.000000     7.600000     0.000000
# 25%         247.000000  1976.000000   103.000000     7.800000    64.000000
# 50%         506.000000  2000.000000   121.000000     7.900000    76.000000
# 75%         751.000000  2011.000000   139.000000     8.100000    86.000000
# max         999.000000  2023.000000   321.000000     9.300000   100.000000
#
#        recaudación(M)
# count     2489.000000
# mean        62.014552
# std        113.887624
# min          0.000000
# 25%          0.280000
# 50%         11.290000
# 75%         70.260000
# max        936.660000

# %%
df_sorted = df.sort_values(by=['rating', 'recaudación(M)'], ascending=False)
df_sorted.head(10)
# Out:
#    indice_global  indice_estricto  \
# 0              0              0.0
# 1              1              1.0
# 2              2              1.0
# 3              3              2.0
# 4              4              2.0
# 5              5              2.0
# 11            11              5.0
# 12            12              5.0
# 13            13              5.0
# 6              6              3.0
#
#                                            título              director  \
# 0                        The Shawshank Redemption        Frank Darabont
# 1                                   The Godfather  Francis Ford Coppola
# 2                                   The Godfather  Francis Ford Coppola
# 3                                 The Dark Knight     Christopher Nolan
# 4                                 The Dark Knight     Christopher Nolan
# 5                                 The Dark Knight     Christopher Nolan
# 11  The Lord of the Rings: The Return of the King         Peter Jackson
# ...

# %%
df_agrupado = df.groupby('género')['género'].count()
df_agrupado
# Out:
# género
# Acción             204
# Animación           82
# Aventura           184
# Biografía          106
# Ciencia Ficción     67
# Comedia            222
# Crimen             200
# Deportes            15
# Drama              721
# Familiar            52
# Fantasía            61
# Film-Noir           22
# Guerra              47
# Historia            44
# Misterio           103
# Musica              31
# Musical             16
# Romance            123
# Terror              33
# Thriller           140
# Western             16
# Name: género, dtype: int64

# %%
df_agrupado = df_agrupado.sort_values(ascending=False)
df_agrupado
# Out:
# género
# Drama              721
# Comedia            222
# Acción             204
# Crimen             200
# Aventura           184
# Thriller           140
# Romance            123
# Biografía          106
# Misterio           103
# Animación           82
# Ciencia Ficción     67
# Fantasía            61
# Familiar            52
# Guerra              47
# Historia            44
# Terror              33
# Musica              31
# Film-Noir           22
# Musical             16
# Western             16
# Deportes            15
# Name: género, dtype: int64
